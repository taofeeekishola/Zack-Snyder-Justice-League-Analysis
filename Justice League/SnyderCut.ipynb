# %%
#importing libariries
import tweepy
import csv
import json
import pandas as pd
import os
import requests
import re
from nltk.tokenize import word_tokenize
import numpy as np

# %%
#load the credentials
with open('twitter_credentials.json', 'r') as file:
    creds = json.load(file)

# %%
auth = tweepy.OAuthHandler(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'])
auth.set_access_token(creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
#Funtion for getting tweets
def get_tweets(search_query, num_tweets):
    # Collect tweets using the Cursor object
    # Each item in the iterator has various attributes that you can access to get information about each tweet
    tweet_list = [tweets for tweets in tweepy.Cursor(api.search,
                                    q=search_query,
                                    lang="en",
                                    tweet_mode='extended').items(num_tweets)]
    # Begin scraping the tweets individually:
    for tweet in tweet_list:
        tweet_id = tweet.id # get Tweet ID result
        created_at = tweet.created_at # get time tweet was created
        text = tweet.full_text # retrieve full tweet text
        location = tweet.user.location # retrieve user location
        retweet = tweet.retweet_count # retrieve number of retweets
        favorite = tweet.favorite_count # retrieve number of likes
        source = tweet.source
        
        with open(r'Justiceleague_2.csv','a', newline='', encoding='utf-8') as csvFile:
            csv_writer = csv.writer(csvFile, delimiter=',') # create an instance of csv object
            csv_writer.writerow([tweet_id, created_at, text, location, retweet, favorite, source]) # write each row

# %%
# Specifying exact phrase to search for. This is not case senstitive
search_words = "Justice League OR #SnyderCut OR #SnyderCutJusticeLeague OR #RestoreTheSnyderVerse OR #restorethesnyderverse"
# Exclude Links, retweets, replies
search_query = search_words + " -filter:retweets AND -filter:replies"
#with open('tweets_bridgerton.csv', encoding='utf-8') as data:
    #latest_tweet = int(list(csv.reader(data))[-1][0]) # Return the most recent tweet ID
get_tweets(search_query,50000) # Call your function and pass in your search query and number of tweets you want to get
# Out:
# Rate limit reached. Sleeping for: 804
# Rate limit reached. Sleeping for: 808
# Rate limit reached. Sleeping for: 815
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 817
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 817
# Rate limit reached. Sleeping for: 816
# Rate limit reached. Sleeping for: 817
# Rate limit reached. Sleeping for: 817
# Rate limit reached. Sleeping for: 813
# Rate limit reached. Sleeping for: 819
# Rate limit reached. Sleeping for: 819
# Rate limit reached. Sleeping for: 818
# Rate limit reached. Sleeping for: 817

# %%
# THIS FUNCTION IS USED TO MINE TWEETS THAT ARE OLDER THAN THE TWEETS YOU HAVE.
def get_tweets2(search_query, num_tweets, max_id_num):
    # Collect tweets using the Cursor object
    # Each item in the iterator has various attributes that you can access to get information about each tweet
    tweet_list = [tweets for tweets in tweepy.Cursor(api.search,
                                    q=search_query,
                                    lang="en",
                                    since_id=max_id_num, # max_id is the oldest tweet id you have
                                    tweet_mode='extended').items(num_tweets)]
    
    # Begin scraping the tweets individually:
    for tweet in tweet_list:
        tweet_id = tweet.id # get Tweet ID result
        created_at = tweet.created_at # get time tweet was created
        text = tweet.full_text # retrieve full tweet text
        location = tweet.user.location # retrieve user location
        retweet = tweet.retweet_count # retrieve number of retweets
        favorite = tweet.favorite_count # retrieve number of likes
        source = tweet.source
        
        with open(r'New_SnyderCut.csv','a', newline='', encoding='utf-8') as csvFile:
            csv_writer = csv.writer(csvFile, delimiter=',') # create an instance of csv object
            csv_writer.writerow([tweet_id, created_at, text, location, retweet, favorite, source]) # write each row

# %%
# Specifying exact phrase to search for. This is not case senstitive
search_words = "Justice League OR #SnyderCut OR #SnyderCutJusticeLeague OR #RestoreTheSnyderVerse OR #restorethesnyderverse"
# Exclude Links, retweets, replies
search_query = search_words + " -filter:retweets AND -filter:replies"
#oldest_tweet = int(list(csv.reader(data))[-1][0])
with open('Justiceleague_2.csv', encoding='utf-8') as data:
    oldest_tweet = int(list(csv.reader(data))[-1][0]) # Return the most recent tweet ID
get_tweets2(search_query,100000,oldest_tweet) # Call your function and pass in your search query and number of tweets you want to get
# Out:
# Rate limit reached. Sleeping for: 764
# Rate limit reached. Sleeping for: 814
# Rate limit reached. Sleeping for: 791
# Rate limit reached. Sleeping for: 807
# Rate limit reached. Sleeping for: 817
# Rate limit reached. Sleeping for: 807
# Rate limit reached. Sleeping for: 809
# Rate limit reached. Sleeping for: 809
# Rate limit reached. Sleeping for: 815
# Rate limit reached. Sleeping for: 797
# Rate limit reached. Sleeping for: 709

# %%
#getting tweet from zack snyder's account
number_of_tweets = 200
tweet_id = []
created_at = []
tweets = []
likes = []
for i in tweepy.Cursor(api.user_timeline, id ='ZackSnyder', tweet_mode = "extended").items(number_of_tweets):
    tweet_id.append(i.id)
    created_at.append(i.created_at)
    tweets.append(i.full_text)
    likes.append(i.favorite_count)

# %%
#giving the data frame headers and saving the new dataframe
df = pd.DataFrame({'tweet_id': tweet_id, 'created_at': time, 'tweets': tweets, 'likes': likes})
df.to_csv('Zack_Snyder.csv', index = False)

# %%
#getting tweet from SnyderCut's account
number_of_tweets = 200
tweet_id = []
created_at = []
tweets = []
likes = []
for i in tweepy.Cursor(api.user_timeline, id ='snydercut', tweet_mode = "extended").items(number_of_tweets):
    tweet_id.append(i.id)
    created_at.append(i.created_at)
    tweets.append(i.full_text)
    likes.append(i.favorite_count)

# %%
#giving the data frame headers and saving the new dataframe
df = pd.DataFrame({'tweet_id': tweet_id, 'created_at': time, 'tweets': tweets, 'likes': likes})
df.to_csv('Zack_Snyder_Cut.csv', index = False)

# %%
#getting tweet from RayFisher's account
number_of_tweets = 500
tweet_id = []
created_at = []
tweets = []
likes = []
for i in tweepy.Cursor(api.user_timeline, id ='ray8fisher', tweet_mode = "extended").items(number_of_tweets):
    tweet_id.append(i.id)
    created_at.append(i.created_at)
    tweets.append(i.full_text)
    likes.append(i.favorite_count)

# %%
#giving the data frame headers and saving the new dataframe
df = pd.DataFrame({'tweet_id': tweet_id, 'created_at': created_at, 'tweets': tweets, 'likes': likes})
df.to_csv('Ray_Fisher.csv', index = False)

# %%
#getting tweet from HBOMax's account
number_of_tweets = 4000
tweet_id = []
created_at = []
tweets = []
likes = []
for i in tweepy.Cursor(api.user_timeline, id ='hbomax', tweet_mode = "extended").items(number_of_tweets):
    tweet_id.append(i.id)
    created_at.append(i.created_at)
    tweets.append(i.full_text)
    likes.append(i.favorite_count)

# %%
df = pd.DataFrame({'tweet_id': tweet_id, 'created_at': created_at, 'tweets': tweets, 'likes': likes})
df.to_csv('HBOmax.csv', index = False)

# %%
#giving the first file a header
name = ['tweet_id', 'created_at', 'tweet', 'location', 'retweet', 'likes', 'source']
df = pd.read_csv('Justiceleague_2.csv', header = None, skiprows = 1, names = name)
df.tail()

# %%
#saving to csv
df.to_csv('Justice_league_1.csv',index=False)

# %%
#displaying the new data
df2 = pd.read_csv('Justice_league_1.csv')
df2.head()
# Out:
#               tweet_id           created_at  \
# 0  1376992630794547203  2021-03-30 20:20:01
# 1  1376992549034979329  2021-03-30 20:19:41
# 2  1376992406441189380  2021-03-30 20:19:07
# 3  1376992216808370181  2021-03-30 20:18:22
# 4  1376992071375056896  2021-03-30 20:17:47
#
#                                                tweet  \
# 0  Exclusive: Connie Nielsen Talks Zack Snyder’s ...
# 1  Honest Trailers | Zack Snyder's Justice League...
# 2  Watching that new Zack Snyder's Justice League...
# 3  Justice League are a man down because, Batman....
# 4     I was on a podcast! 👍🏻 https://t.co/HX3x51Tswv
#
#                      location  retweet  likes               source
# 0             Albuquerque, NM        0      0               Buffer
# 1                         NaN        0      0      Twitter Web App
# 2                     Glasgow        0      0   Twitter for iPhone
# 3  36°49′E / 1.283°S 36.817°E        0      0  Twitter for Android
# ...

# %%
#giving the second file a header
name = ['tweet_id', 'created_at', 'tweet', 'location', 'retweet', 'likes', 'source']
df = pd.read_csv('New_SnyderCut.csv', header = None, skiprows = 1, names = name)
df.tail()
# Out:
#                   tweet_id           created_at  \
# 30353  1375176473313705989  2021-03-25 20:03:15
# 30354  1375176445941583874  2021-03-25 20:03:08
# 30355  1375176291381432322  2021-03-25 20:02:32
# 30356  1375176214902673414  2021-03-25 20:02:13
# 30357  1375176185106337798  2021-03-25 20:02:06
#
#                                                    tweet  \
# 30353  Zack Snyder’s Justice league is one of the bes...
# 30354  JUSTICE LEAGUE Fans Campaigning for WARNER BRO...
# 30355  Justice League Flash is lightskin https://t.co...
# 30356  This will never end. Justice will prevail  #Re...
# 30357  Okay, but when are we getting the sepia versio...
#
#                             location  retweet  likes              source
# 30353            Kaliningrad, Russia        0      0  Twitter for iPhone
# 30354           Barb deserved better       75    295           TweetDeck
# 30355  black lives matta • they/them        2      7  Twitter for iPhone
# ...

# %%
#saving to csv
df.to_csv('Justiceleague_2.csv',index=False)

# %%
#merging the two csvs
master_df = pd.DataFrame()

for file in os.listdir(os.getcwd()):
    if file.endswith('.csv'):
        master_df = master_df.append(pd.read_csv(file))
        
master_df.to_csv('Justice_League.csv', index = False)

# %%
tweet_df = pd.read_csv('Justice_League.csv')
tweet_df.tail()
# Out:
#                    tweet_id           created_at  \
# 110389  1375176473313705989  2021-03-25 20:03:15
# 110390  1375176445941583874  2021-03-25 20:03:08
# 110391  1375176291381432322  2021-03-25 20:02:32
# 110392  1375176214902673414  2021-03-25 20:02:13
# 110393  1375176185106337798  2021-03-25 20:02:06
#
#                                                     tweet  \
# 110389  Zack Snyder’s Justice league is one of the bes...
# 110390  JUSTICE LEAGUE Fans Campaigning for WARNER BRO...
# 110391  Justice League Flash is lightskin https://t.co...
# 110392  This will never end. Justice will prevail  #Re...
# 110393  Okay, but when are we getting the sepia versio...
#
#                              location  retweet  likes              source
# 110389            Kaliningrad, Russia        0      0  Twitter for iPhone
# 110390           Barb deserved better       75    295           TweetDeck
# 110391  black lives matta • they/them        2      7  Twitter for iPhone
# ...

# %% [markdown]
# # CLEANING THE DATA

# %%
tweet_df.shape #Get number of rows and columns
# Out:
# (110394, 7)

# %%
tweet_df.duplicated(subset='tweet_id').sum() # Check for duplicate values
# Out:
# 59713

# %%
tweet_df=tweet_df.drop_duplicates(subset=['tweet_id']) # drop duplicate values

# %%
tweet_df.shape # Check the shape after dropping duplicates
# Out:
# (50681, 7)

# %%
tweet_df.isna().any() # Check for "NaN" values
# Out:
# tweet_id      False
# created_at    False
# tweet         False
# location       True
# retweet       False
# likes         False
# source         True
# dtype: bool

# %%
tweet_df['location']=tweet_df['location'].fillna('No location') # Replace "NaN" values with "No Location"

# %%
tweet_df.head()
# Out:
#               tweet_id           created_at  \
# 0  1376992630794547203  2021-03-30 20:20:01
# 1  1376992549034979329  2021-03-30 20:19:41
# 2  1376992406441189380  2021-03-30 20:19:07
# 3  1376992216808370181  2021-03-30 20:18:22
# 4  1376992071375056896  2021-03-30 20:17:47
#
#                                                tweet  \
# 0  Exclusive: Connie Nielsen Talks Zack Snyder’s ...
# 1  Honest Trailers | Zack Snyder's Justice League...
# 2  Watching that new Zack Snyder's Justice League...
# 3  Justice League are a man down because, Batman....
# 4     I was on a podcast! 👍🏻 https://t.co/HX3x51Tswv
#
#                      location  retweet  likes               source
# 0             Albuquerque, NM        0      0               Buffer
# 1                 No location        0      0      Twitter Web App
# 2                     Glasgow        0      0   Twitter for iPhone
# 3  36°49′E / 1.283°S 36.817°E        0      0  Twitter for Android
# ...

# %%
tweet_df['source']=tweet_df['source'].fillna('No source') # Replace "NaN" values with "No source"

# %%
tweet_df.tail()
# Out:
#                    tweet_id           created_at  \
# 108995  1375229897543716864  2021-03-25 23:35:32
# 109043  1375228140126003203  2021-03-25 23:28:33
# 109799  1375199195490095105  2021-03-25 21:33:32
# 110027  1375190246434951170  2021-03-25 20:57:59
# 110256  1375182261096615937  2021-03-25 20:26:15
#
#                                                     tweet  \
# 108995  This is canon, this is real, this is justice l...
# 109043  Why Zack Snyder's Justice League Is Changing M...
# 109799  Zack Snyder’s Justice League was easily the be...
# 110027  We believe in Justice!!! Restore The Snyder Ve...
# 110256  im sending all my girl best friends to dennis ...
#
#                             location  retweet  likes              source
# 108995  Cuauhtémoc, Distrito Federal        0      0     Twitter Web App
# 109043             Diksmuide, België        0      0             dlvr.it
# 109799                   No location        1      1  Twitter for iPhone
# ...

# %%
#functioon for getting latitude and longitude of location provided by twitter user
API_KEY = 'AIzaSyAxRUb-D6DkSPFGWSAWM_qoipZOkt9HZFc'

def getGeoCoord(address):
    if address != 'No location':
        params = {
        'key': API_KEY,
        'address': address.replace(' ', '+')
        }

        base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
        response = requests.get(base_url, params=params)
        data = response.json()
        if data['status'] == 'OK':
            result = data['results'][0]
            location = result['geometry']['location']
            return location['lat'], location['lng']

# %%
tweet_df['Location_data']=tweet_df['location'].apply(getGeoCoord) # Apply getCoordinates Function

# %%
tweet_df.head()
# Out:
#               tweet_id           created_at  \
# 0  1376992630794547203  2021-03-30 20:20:01
# 1  1376992549034979329  2021-03-30 20:19:41
# 2  1376992406441189380  2021-03-30 20:19:07
# 3  1376992216808370181  2021-03-30 20:18:22
# 4  1376992071375056896  2021-03-30 20:17:47
#
#                                                tweet  \
# 0  Exclusive: Connie Nielsen Talks Zack Snyder’s ...
# 1  Honest Trailers | Zack Snyder's Justice League...
# 2  Watching that new Zack Snyder's Justice League...
# 3  Justice League are a man down because, Batman....
# 4     I was on a podcast! 👍🏻 https://t.co/HX3x51Tswv
#
#                      location  retweet  likes               source  \
# 0             Albuquerque, NM        0      0               Buffer
# 1                 No location        0      0      Twitter Web App
# 2                     Glasgow        0      0   Twitter for iPhone
# 3  36°49′E / 1.283°S 36.817°E        0      0  Twitter for Android
# ...

# %%
#spliting the latitude and longitutide into different columns
tweet_df[['latitude','longitude']] = pd.DataFrame(tweet_df['Location_data'].tolist(),index=tweet_df.index)

# %%
tweet_df.head()
# Out:
#               tweet_id           created_at  \
# 0  1376992630794547203  2021-03-30 20:20:01
# 1  1376992549034979329  2021-03-30 20:19:41
# 2  1376992406441189380  2021-03-30 20:19:07
# 3  1376992216808370181  2021-03-30 20:18:22
# 4  1376992071375056896  2021-03-30 20:17:47
#
#                                                tweet  \
# 0  Exclusive: Connie Nielsen Talks Zack Snyder’s ...
# 1  Honest Trailers | Zack Snyder's Justice League...
# 2  Watching that new Zack Snyder's Justice League...
# 3  Justice League are a man down because, Batman....
# 4     I was on a podcast! 👍🏻 https://t.co/HX3x51Tswv
#
#                      location  retweet  likes               source  \
# 0             Albuquerque, NM        0      0               Buffer
# 1                 No location        0      0      Twitter Web App
# 2                     Glasgow        0      0   Twitter for iPhone
# 3  36°49′E / 1.283°S 36.817°E        0      0  Twitter for Android
# ...

# %%
#function to remove and get hastags
def getHashtags(tweet):
    tweet = tweet.lower()  #has to be in place
    tweet = re.findall(r'\#\w+',tweet) # Remove hastags with REGEX
    return " ".join(tweet)

# %%
tweet_df['Hashtags'] = tweet_df['tweet'].apply(getHashtags)
tweet_df.head()
# Out:
#               tweet_id           created_at  \
# 0  1376992630794547203  2021-03-30 20:20:01
# 1  1376992549034979329  2021-03-30 20:19:41
# 2  1376992406441189380  2021-03-30 20:19:07
# 3  1376992216808370181  2021-03-30 20:18:22
# 4  1376992071375056896  2021-03-30 20:17:47
#
#                                                tweet  \
# 0  Exclusive: Connie Nielsen Talks Zack Snyder’s ...
# 1  Honest Trailers | Zack Snyder's Justice League...
# 2  Watching that new Zack Snyder's Justice League...
# 3  Justice League are a man down because, Batman....
# 4     I was on a podcast! 👍🏻 https://t.co/HX3x51Tswv
#
#                      location  retweet  likes               source  \
# 0             Albuquerque, NM        0      0               Buffer
# 1                 No location        0      0      Twitter Web App
# 2                     Glasgow        0      0   Twitter for iPhone
# 3  36°49′E / 1.283°S 36.817°E        0      0  Twitter for Android
# ...

# %%
hashtags_list = tweet_df['Hashtags'].tolist()

#iterate over all hashtags so they can be split where there is more than one hashtag per row
hashtags = []
for item in hashtags_list:
    item = item.split()
    for i in item:
        hashtags.append(i)

# Use the Built-in Python Collections module to determine Unique count of all hashtags used
from collections import Counter
counts = Counter(hashtags)
hashtags_df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
hashtags_df.columns = ['Hashtags', 'Count']
hashtags_df.sort_values(by='Count', ascending=False, inplace=True)
print (f'Total Number of Unique Hashtags is: {hashtags_df.shape[0]}.')
# Out:
# Total Number of Unique Hashtags is: 3683.

# %%
hashtags_df["Percentage"] = 100*(hashtags_df["Count"]/hashtags_df['Count'].sum())
hashtags_df = hashtags_df.head(10)

# %%
hashtags_df
# Out:
#                       Hashtags  Count  Percentage
# 5       #restorethesnyderverse   6374   21.411535
# 11                  #snydercut   2656    8.922033
# 14   #zacksnydersjusticeleague   2220    7.457422
# 47              #justiceleague   1414    4.749908
# 4      #restorethesnyderverese    462    1.551950
# 173             #justiceisgray    458    1.538513
# 27     #justiceleaguesnydercut    419    1.407504
# 57                     #batman    408    1.370553
# 84                   #superman    389    1.306728
# 41      #restorethesynderverse    367    1.232826

# %%
#list of important justice league characters
justiceleague_characters = ['batman', 'superman', 'wonderwoman', 'flash', 'cyborg', 'aquaman', 'darkside', 'steppenwolf'
                        'joker', 'deathstroke', 'lex luthor', 'amazons', 'barry allen' ]

# %%
# Function to extract Bridgerton Characters from each Tweet
def getMovieCharacters(tweet):
    tweet = tweet.lower() # Reduce tweet to lower case
    tweet_tokens = word_tokenize(tweet) # split each word in the tweet for parsing
    movie_characters = [char for char in tweet_tokens if char in justiceleague_characters] # extract movie characters
    return " ".join(movie_characters)

# %%
# Extract Movie characters to a new column
tweet_df['Movie_Characters'] = tweet_df['tweet'].apply(getMovieCharacters)
tweet_df.tail()
# Out:
#                    tweet_id           created_at  \
# 108995  1375229897543716864  2021-03-25 23:35:32
# 109043  1375228140126003203  2021-03-25 23:28:33
# 109799  1375199195490095105  2021-03-25 21:33:32
# 110027  1375190246434951170  2021-03-25 20:57:59
# 110256  1375182261096615937  2021-03-25 20:26:15
#
#                                                     tweet  \
# 108995  This is canon, this is real, this is justice l...
# 109043  Why Zack Snyder's Justice League Is Changing M...
# 109799  Zack Snyder’s Justice League was easily the be...
# 110027  We believe in Justice!!! Restore The Snyder Ve...
# 110256  im sending all my girl best friends to dennis ...
#
#                             location  retweet  likes              source  \
# 108995  Cuauhtémoc, Distrito Federal        0      0     Twitter Web App
# 109043             Diksmuide, België        0      0             dlvr.it
# 109799                   No location        1      1  Twitter for iPhone
# ...

# %%
characters_list = tweet_df['Movie_Characters'].tolist()

#iterate over all hashtags so they can be split where there is more than one hashtag per row
characters = []
for item in characters_list:
    item = item.split()
    for i in item:
        characters.append(i)

# Use the Built-in Python Collections module to determine Unique count of all hashtags used
from collections import Counter
counts = Counter(characters)
characters_df = pd.DataFrame.from_dict(counts, orient='index').reset_index()
characters_df.columns = ['Movie_Characters', 'Count']
characters_df.sort_values(by='Count', ascending=False, inplace=True)
print (f'Total Number of Unique Characters is: {characters_df.shape[0]}.')
characters_df.head(10)

# %%
characters_df['Percentage'] = 100*(characters_df['Count'] / characters_df['Count'].sum())
characters_df

# %%
#saving to csv
characters_df.to_csv('characters.csv',index=False)

# %%
tweet_df.drop(['location','Location_data',], axis = 1, inplace = True)

# %%
tweet_df.head()
# Out:
#               tweet_id           created_at  \
# 0  1376992630794547203  2021-03-30 20:20:01
# 1  1376992549034979329  2021-03-30 20:19:41
# 2  1376992406441189380  2021-03-30 20:19:07
# 3  1376992216808370181  2021-03-30 20:18:22
# 4  1376992071375056896  2021-03-30 20:17:47
#
#                                                tweet  retweet  likes  \
# 0  Exclusive: Connie Nielsen Talks Zack Snyder’s ...        0      0
# 1  Honest Trailers | Zack Snyder's Justice League...        0      0
# 2  Watching that new Zack Snyder's Justice League...        0      0
# 3  Justice League are a man down because, Batman....        0      0
# 4     I was on a podcast! 👍🏻 https://t.co/HX3x51Tswv        0      0
#
#                 source                           Hashtags Movie_Characters  \
# 0               Buffer  #tv #video #movies #entertainment
# 1      Twitter Web App
# 2   Twitter for iPhone
# 3  Twitter for Android                                              batman
# ...

# %%
tweet_df.to_csv('Justice_League_final.csv',index=False)
